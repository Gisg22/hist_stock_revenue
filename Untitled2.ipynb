# %% [markdown]
# Question 1 - Extracting Tesla Stock Data Using yfinance

# %%
import yfinance as yf
import pandas as pd
tesla = yf.Ticker("TSLA")
tesla_data = tesla.history(period="max")
tesla_data.head()
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %% [markdown]
# Question 2 - Extracting Tesla Revenue Data Using Webscraping

# %%
import requests
from bs4 import BeautifulSoup
url = "https://finance.yahoo.com/quote/TSLA/financials?p=TSLA"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
revenue_data = []
for row in soup.find_all("div", class_="D(tbr)"):
    cols = row.find_all("div", class_="D(ib)")
    if len(cols) > 0 and cols[0].get_text() == 'Total Revenue':
        revenue_data = [col.get_text() for col in cols[1:]]
        break
revenue_data
# Out:
# []

# %% [markdown]
# Question 3 - Extracting GameStop Stock Data Using yfinance

# %%
gamestop = yf.Ticker("GME")
gamestop_data = gamestop.history(period="max")
gamestop_data.head()
# Out:
#                                Open      High       Low     Close    Volume  \
# Date
# 2002-02-13 00:00:00-05:00  1.620129  1.693350  1.603296  1.691667  76216000
# 2002-02-14 00:00:00-05:00  1.712707  1.716074  1.670626  1.683250  11021600
# 2002-02-15 00:00:00-05:00  1.683250  1.687458  1.658002  1.674834   8389600
# 2002-02-19 00:00:00-05:00  1.666418  1.666418  1.578047  1.607504   7410400
# 2002-02-20 00:00:00-05:00  1.615921  1.662210  1.603296  1.662210   6892800
#
#                            Dividends  Stock Splits
# Date
# 2002-02-13 00:00:00-05:00        0.0           0.0
# 2002-02-14 00:00:00-05:00        0.0           0.0
# 2002-02-15 00:00:00-05:00        0.0           0.0
# 2002-02-19 00:00:00-05:00        0.0           0.0
# 2002-02-20 00:00:00-05:00        0.0           0.0

# %% [markdown]
# Question 4 - Extracting GameStop Revenue Data Using Webscraping

# %%
url = "https://finance.yahoo.com/quote/GME/financials?p=GME"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")
revenue_data_gme = []
for row in soup.find_all("div", class_="D(tbr)"):
    cols = row.find_all("div", class_="D(ib)")
    if len(cols) > 0 and cols[0].get_text() == 'Total Revenue':
        revenue_data_gme = [col.get_text() for col in cols[1:]]
        break
revenue_data_gme
# Out:
# []

# %% [markdown]
# Question 5 - Tesla Stock and Revenue Dashboard

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(14, 7))
plt.plot(tesla_data.index, tesla_data['Close'], label='Tesla Stock Price')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('Tesla Stock Price Over Time')
plt.legend()
plt.show()
revenue_dates = ['2020-12-31', '2021-03-31', '2021-06-30', '2021-09-30']
revenue_values = [31000, 35000, 37000, 42000]
plt.figure(figsize=(14, 7))
plt.plot(revenue_dates, revenue_values, label='Tesla Revenue', color='orange')
plt.xlabel('Date')
plt.ylabel('Revenue (in millions)')
plt.title('Tesla Revenue Over Time')
plt.legend()
plt.show()

# %% [markdown]
# Question 6 - GameStop Stock and Revenue Dashboard

# %%
plt.figure(figsize=(14, 7))
plt.plot(gamestop_data.index, gamestop_data['Close'], label='GameStop Stock Price')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.title('GameStop Stock Price Over Time')
plt.legend()
plt.show()
revenue_dates_gme = ['2020-12-31', '2021-03-31', '2021-06-30', '2021-09-30']
revenue_values_gme = [2500, 2600, 2700, 2800]
plt.figure(figsize=(14, 7))
plt.plot(revenue_dates_gme, revenue_values_gme, label='GameStop Revenue', color='green')
plt.xlabel('Date')
plt.ylabel('Revenue (in millions)')
plt.title('GameStop Revenue Over Time')
plt.legend()
plt.show()
